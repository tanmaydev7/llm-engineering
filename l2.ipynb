# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4.1-mini")
tokens = encoding.encode("Hi my name is SOmething")

# %%
tokens
# Out:
# [12194, 922, 1308, 382, 10421, 76, 3272]

# %%
for token_id in tokens:
    token_decoded_text = encoding.decode([token_id])
    print(f"{token_id} => {token_decoded_text}")
# Out:
# 12194 => Hi
# 922 =>  my
# 1308 =>  name
# 382 =>  is
# 10421 =>  SO
# 76 => m
# 3272 => ething

# %%
# Out:
# 'm!'
